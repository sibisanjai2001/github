# %%
import pandas as pd
datas=pd.read_csv("adult.csv")

# %%
datas.head()
datas.info()
datas.describe()
datas.tail()
datas.shape
datas.index
datas.empty
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ages            32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
#  15  country         32561 non-null  object
# dtypes: int64(6), object(10)
# memory usage: 4.0+ MB
# False

# %%
datas.columns
datas.size
datas.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
datas.loc[1]
datas.loc[[10,40]]
datas.dtypes
# DataFrame.to_numpy() 
datas[0:2]
datas[['age','workclass']]
datas[0:2][['age','workclass']]
datas[20:22]
#See more in Selection by Label using DataFrame.loc() or DataFrame.at().
# Out:
#     age workclass  fnlwgt  education  education.num marital.status  \
# 20   37   Private  188774  Bachelors             13  Never-married
# 21   29   Private   77009       11th              7      Separated
#
#          occupation   relationship   race     sex  capital.gain  capital.loss  \
# 20  Exec-managerial  Not-in-family  White    Male             0          2824
# 21            Sales  Not-in-family  White  Female             0          2754
#
#     hours.per.week native.country income
# 20              40  United-States   >50K
# 21              42  United-States  <=50K

# %%
# pratice started from here

# %%
#Handling missing
datas.isna()
#Filtering 
datas[datas["age"]>88]
datas[(datas["age"]>88) & (datas["sex"]=="Male")]
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 199     90           Private   51744       HS-grad              9
# 1739    90         Local-gov  227796       Masters             14
# 1742    90           Private   87372   Prof-school             15
# 2241    90  Self-emp-not-inc  155981     Bachelors             13
# 2296    90           Private   46786     Bachelors             13
# 2299    90           Private  175491       HS-grad              9
# 2947    90         Local-gov  153602       HS-grad              9
# 3776    90  Self-emp-not-inc   82628       HS-grad              9
# 3854    90         Local-gov  214594       7th-8th              4
# 4224    90                 ?   39824       HS-grad              9
# 5896    90           Private  221832     Bachelors             13
# 6227    90           Private   52386  Some-college             10
# 7756    90           Private  313986          11th              7
# ...

# %%
#Adding/modifying columns.
datas["country"]="USA"

# %%
datas.columns
datas["new_age"]=datas["age"]+5  #creating new column
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income', 'country', 'new_age'],
#       dtype='object')

# %%
datas.rename(columns={"age":"ages"},inplace=True)   #if you use this then only permentally change the column name
datas.columns
# Out:
# Index(['ages', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income', 'country'],
#       dtype='object')

# %%
#grouping
temp=datas.groupby("education")["ages"].agg(["min","max","mean","count","sum"])
print(temp)
# Out:
#               min  max       mean  count     sum
# education
# 10th           17   90  37.429796    933   34922
# 11th           17   90  32.355745   1175   38018
# 12th           17   79  32.000000    433   13856
# 1st-4th        19   90  46.142857    168    7752
# 5th-6th        17   84  42.885886    333   14281
# 7th-8th        17   90  48.445820    646   31296
# 9th            17   90  41.060311    514   21105
# Assoc-acdm     19   90  37.381443   1067   39886
# Assoc-voc      19   84  38.553546   1382   53281
# Bachelors      19   90  38.904949   5355  208336
# Doctorate      24   80  47.702179    413   19701
# HS-grad        17   90  38.974479  10501  409271
# Masters        18   90  44.049913   1723   75898
# Preschool      19   75  42.764706     51    2181
# Prof-school    25   90  44.746528    576   25774
# Some-college   17   90  35.756275   7291  260699

# %%
datas.isna().sum()
datas.rename
datas.isnull().sum()
# Out:
# ages              0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# country           0
# dtype: int64
